# %%
# from delicacy.svglib.colors.palette import PaletteGenerator, PREFERRED_PALETTES
# from hashlib import sha3_512
# from bitstring import BitArray

# from IPython.display import HTML, display

# def display_hex(color_codes):
#     parent = "<div style='display: flex'>{}\n"
#     child = []
#     for color in color_codes:
#         color_square = f"<div style='width: 100px; height: 100px; background-color: {color};'></div>"
#         child.append(color_square)
#     child = "\n\t" + "\n\t".join(child)
#     html = parent.format(child) + "</div>"
#     display(HTML(html))

# phrase = 'hey'    
# hex = sha3_512(phrase.encode()).hexdigest()
# seed = BitArray(hex=hex).uint
# palette = PREFERRED_PALETTES[2]
# hexes = [color.to_hex() for color in PaletteGenerator(palette, seed=seed).generate()]
# display_hex(hexes)

# %%
from delicacy.config import COLLECTION_DIR
from delicacy.igen.collection import Collection
from delicacy.igen.igen import ImageGenerator

robot_path = COLLECTION_DIR / 'robot'
robot_collection = Collection("Robot", robot_path)
robot_gen = ImageGenerator(robot_collection)

# %%
from delicacy.saturn.saturn import Reah, Dione, Tethys
from delicacy.generate import generate

phrase = 'delicacy'
dark_theme = '#09132b'
light_theme = '#ced5e5'
background = dark_theme

# %%
# %time generate(phrase, Reah, robot_gen, background_color=background)
# Out:
# CPU times: user 86.8 ms, sys: 762 µs, total: 87.5 ms
# Wall time: 52.7 ms
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>

# %%
# %time generate(phrase, Dione, robot_gen, background_color=background)
# Out:
# CPU times: user 86.1 ms, sys: 588 µs, total: 86.7 ms
# Wall time: 63 ms
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>

# %%
# %time generate(phrase, Tethys, robot_gen, background_color=background)
# Out:
# CPU times: user 62.9 ms, sys: 442 µs, total: 63.4 ms
# Wall time: 43.4 ms
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>

# %%
import random
import string

def generate_password(length):
    """Generates a random password of the specified length."""
    # Define the character sets to use in the password
    lowercase_letters = string.ascii_lowercase
    uppercase_letters = string.ascii_uppercase
    digits = string.digits
    symbols = '' or  string.punctuation
    
    # Combine the character sets into one string
    all_characters = lowercase_letters + uppercase_letters + digits + symbols
    
    # Generate the password using random.choice()
    password = ""
    for i in range(length):
        password += random.choice(all_characters)
    
    return password

# %%
phrases = [generate_password(10) for _ in range(50)]
gens = random.choices([Reah, Dione, Tethys], k = 50)
images = [generate(p, g, robot_gen, background_color=background) for p,g in zip(phrases, gens)]
for image in images:
    display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x320>
# ...
